# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_data = np.load('/Users/pipipu/Desktop/HAGEN/HAGEN-code/crime-data/CRIME-CHICAGO/8/train.npz')

# %%
train_data.files
# Out:
# ['x', 'y', 'x_offsets', 'y_offsets']

# %%
label_0 = np.sum(train_data['y'][:,0,:,:],axis=0)[:,0]
label_1 = np.sum(train_data['y'][:,0,:,:],axis=0)[:,1]
label_2 = np.sum(train_data['y'][:,0,:,:],axis=0)[:,2]

# %%
plt.bar(range(label_0.shape[0]), label_0,label = 'Theft')
plt.bar(range(label_0.shape[0]), label_1,label = 'Criminal Damage')
plt.bar(range(label_0.shape[0]), label_2,label = 'Nacrotic')
plt.legend()
plt.show()

# %%
label_1 = np.sum(train_data['x'][:,1,:,:],axis=0)[:,0]
plt.bar(range(label_1.shape[0]), label_1)
# Out:
# <BarContainer object of 77 artists>

# %%
label_2 = np.sum(train_data['x'][:,2,:,:],axis=0)[:,0]
plt.bar(range(label_2.shape[0]), label_2)
# Out:
# <BarContainer object of 77 artists>

# %%
label_3 = np.sum(train_data['x'][:,3,:,:],axis=0)[:,0]
plt.bar(range(label_2.shape[0]), label_3)
# Out:
# <BarContainer object of 113 artists>
